# %%
import re

import pandas as pd
from bs4 import BeautifulSoup
from requests import get
from unidecode import unidecode


def ler_propostas():
    res = get('http://speakerfight.com/events/python-brasil12-apresentacoes/')
    soup = BeautifulSoup(res.content, 'html.parser')
    div_event_proposals = soup.find('div', id='event-proposals')
    propostas = div_event_proposals.find_all(attrs={'class': 'panel-body'})
    for p in propostas:
        titulo = p.h3.a.text.strip()
        autor = p.find('p', attrs={'class': 'proposal-metadata'}).a.text
        match = re.findall('(\[ *(.*?) *\])', titulo)
        if match:
            trecho, miolo = match[0]
            titulo = titulo.replace(trecho, '')
            categorias = re.split(' *, *', miolo)
            for cat in categorias:
                yield autor, titulo, cat
        else:
            yield autor, titulo, '???'

propostas = sorted(ler_propostas(), key=lambda x: unidecode(str(x)).lower())


df = pd.DataFrame(propostas, columns=['autor', 'titulo', 'categoria'])
df.set_index(['autor', 'categoria'])
# Out:
#                                                                                          titulo
# autor                      categoria
# Jos'e Guilherme Tavares    ???                Fazendo fila com e tabelando com o "Aipo" (SQS...
# alexandre.prates           intermediário       REGEX - Do iniciante ao Avançado (usando Python)
#                            Escalabilidade                            Alta performance em Python
#                            Performance        Truques para melhorar a performance de sua apl...
#                            ???                                  Visualização de dados em Python
# Alisson de Menezes         ???                                     Heimdall Guard - Spam Filter
# Álvaro Justen              ???                             Dados Tabulares: A Maneira Pythônica
# Anderson Resende           ???                A Programação Funcional em Python, de forma si...
# André Ericson              ???                                                Django e React.js
#                            ???                       Estrutura de dados e collections em Python
# annanda                    ???                Como usei o Python para ajudar animais abandon...
# Artur Sousa                DevOps             Automatizando a infraestrutura e disponibiliza...
#                            Web                Automatizando a infraestrutura e disponibiliza...
# asivolella                 Machine Learning         Treinando Modelos Ensemble com Scikit-Learn
# Barbara Moraes Vicente     ???                                 PyRobô: Automatização com Python
# betacampello               ???                Descobrindo as menores distâncias entre divers...
# Bruno Marques              REST               REST com um quê de KISS: apresentando a biblio...
#                            Web                REST com um quê de KISS: apresentando a biblio...
# Bruno Rocha                ???                APIs escalaveis, simples e com boa documentaçã...
#                            ???                Como criar mapas dinâmicos e cheios de firulas...
#                            ???                Roubando (idéias) dos frameworks ricos e entre...
# dakerfp                    ???                              Construíndo a Matrix com Tensorflow
# Daniel Bastos              Teste                     BDD com Python, facilite a vida de todos!
# dannluciano                ???                             Navegando no Codigo Fonte do Django.
#                            ???                                            Python e Criptografia
# Diego Guimarães            Mobile              Kivy: Fazendo Aplicativos para Celular com Py...
# Elias Dorneles             ???                Aprimorando as habilidades de debugging e trou...
#                            ???                Portando para Python 3 mantendo retrocompatibi...
# Elias Tandel Barrionovo    ???                                        DSLs embarcadas em Python
#                            ???                    Nobody expects the floating point inquisition
# ...                                                                                         ...
# Marcos Cardoso             ???                Como a Globosat utiliza Python para distribuiç...
# Melissa Weber Mendonça     ???                Fortran (ainda) não morreu: utilizando Fortran...
#                            ???                          Produzindo lindos relatórios com Pweave
# neldevfull                 ???                                     Porquê Mr. Robot usa Python?
# Nicolle Cysneiros          ???                Graph Databases: Discutindo o Relacionamento d...
# Nielson Santana            ???                Dokku - Mini-Heroku que mudou minha vida de De...
#                            ???                Gerenciando multiplos projetos em multiplos am...
# ocarneiro                  Iniciantes          Python para malabaristas - uma introdução ao ...
# Patricia Lopes             Web                        Search Engines com Python e Elasticsearch
# Pedro Henrique             ???                                  Desenvolvimento web: é difícil?
# Raphael Amorim             ???                                          500 Dias de Open Source
# Renan Rodrigues            Python Científico  Apresentação da Contabilização de Nucleotídios...
#                            Comunidade         Como o Python Ficou Mundialmente Conhecido com...
#                            Iniciantes         Como o Python Ficou Mundialmente Conhecido com...
#                            Python Científico  Como o Python Ficou Mundialmente Conhecido com...
#                            Python Científico  Como Otimizar um Problema Utilizando Algoritmo...
#                            Carreira           O Mercado de Python e a sua Empregabilidade no...
#                            Iniciantes         O Mercado de Python e a sua Empregabilidade no...
#                            Iniciantes                 Paradigma Orientado a Objetos com Python
#                            Comunidade         Python para Desenvolvedores: Uma Visão do Pyth...
#                            Desktop            Python para Desenvolvedores: Uma Visão do Pyth...
#                            Python Científico  Python para Desenvolvedores: Uma Visão do Pyth...
# Renato dos Santos Oliveira ???                                      Django Views: Boas práticas
# Ricardo Roberto de Lima    ???                Uma Orquestração de componentes baseados em MD...
# Robson Luis Junior         ???                                   big data disruptiva com python
# Roselma Mendes             ???                             Construindo uma aplicação web segura
# ssjunior                   Web                 Escalabilidade de aplicativos utilizando Cele...
#                            Web                       Real Time Django usando Redis e Websockets
# Tarsis Azevedo             ???                A Little Talk about Semaphores (ou padrões de ...
#                            ???                                         Performance Analysis 101
#
# [102 rows x 1 columns]

# %%
df.groupby(['autor', 'titulo']).agg(lambda x: ', '.join(x))
# Out:
#                                                                                                                   categoria
# autor                            titulo
# Alisson de Menezes               Heimdall Guard - Spam Filter                                                           ???
# Anderson Resende                 A Programação Funcional em Python, de forma sim...                                     ???
# André Ericson                    Django e React.js                                                                      ???
#                                  Estrutura de dados e collections em Python                                             ???
# Artur Sousa                      Automatizando a infraestrutura e disponibilizan...                             DevOps, Web
# Barbara Moraes Vicente           PyRobô: Automatização com Python                                                       ???
# Bruno Marques                    REST com um quê de KISS: apresentando a bibliot...                               REST, Web
# Bruno Rocha                      APIs escalaveis, simples e com boa documentação...                                     ???
#                                  Como criar mapas dinâmicos e cheios de firulas ...                                     ???
#                                  Roubando (idéias) dos frameworks ricos e entreg...                                     ???
# Daniel Bastos                    BDD com Python, facilite a vida de todos!                                            Teste
# Diego Guimarães                   Kivy: Fazendo Aplicativos para Celular com Python                                  Mobile
# Elias Dorneles                   Aprimorando as habilidades de debugging e troub...                                     ???
#                                  Portando para Python 3 mantendo retrocompatibil...                                     ???
# Elias Tandel Barrionovo          DSLs embarcadas em Python                                                              ???
#                                  Nobody expects the floating point inquisition                                          ???
# Ezequiel Bertti                  De grão em grão, usando A/B Test para aumentar ...                                     ???
# Felipe Arruda Pontes             Docker Overkill - Coisas interessantes, mirabol...                                     ???
# Felippe da Motta Raposo          Iniciando a jornada como sistemas distribuídos,...                                     ???
# Fernando Ashikaga                Hoje sou um professor FELIZ: Python no ensino d...                                     ???
# Filipe A Ximenes                 Isolando os dados dos seus clientes com Django                                         ???
#                                  O que é esse tal de REST?                                                              ???
#                                  Testando sua API web                                                                   ???
# Filipe Pires Alvarenga Fernandes Easy slippy maps with folium                                                           ???
# Flávio Juvenal                   Como fazer boas libs? O que torna uma bibliotec...                                     ???
#                                  Como procurar questões técnicas no Google, ou s...                                     ???
#                                  Fazendo apresentações real-time com Jupyter                                            ???
#                                  HATEOAS: construindo APIs realmente RESTful                                            ???
#                                  Python WAT: quando Python não é como você espera                                       ???
# GrupoCITEC                       Como deixar a lógica do sistema na mão do clien...                                     ???
# ...                                                                                                                     ...
# Renan Rodrigues                  Paradigma Orientado a Objetos com Python                                        Iniciantes
#                                  Python para Desenvolvedores: Uma Visão do Pytho...  Comunidade, Desktop, Python Científico
# Renato dos Santos Oliveira       Django Views: Boas práticas                                                            ???
# Ricardo Roberto de Lima          Uma Orquestração de componentes baseados em MDA...                                     ???
# Robson Luis Junior               big data disruptiva com python                                                         ???
# Roselma Mendes                   Construindo uma aplicação web segura                                                   ???
# Tarsis Azevedo                   A Little Talk about Semaphores (ou padrões de s...                                     ???
#                                  Performance Analysis 101                                                               ???
# alexandre.prates                  REGEX - Do iniciante ao Avançado (usando Python)                            intermediário
#                                  Alta performance em Python                                                  Escalabilidade
#                                  Truques para melhorar a performance de sua apli...                             Performance
#                                  Visualização de dados em Python                                                        ???
# annanda                          Como usei o Python para ajudar animais abandonados                                     ???
# asivolella                        Treinando Modelos Ensemble com Scikit-Learn                              Machine Learning
# betacampello                     Descobrindo as menores distâncias entre diversa...                                     ???
# dakerfp                          Construíndo a Matrix com Tensorflow                                                    ???
# dannluciano                      Navegando no Codigo Fonte do Django.                                                   ???
#                                  Python e Criptografia                                                                  ???
# elinaldo                         Minerando a Internet com Python e GO                                                   ???
# emiliosimoni                     Prevendo futuro com machine learn                                                      ???
# gcaminha                         Construindo websites com Django-CMS                                                    ???
# jonatas.cd                        Programação transcultural                                                        Carreira
# jvaz                             Como desenvolver e manter aplicações em ambient...                                     ???
# lidymonteiro                     Matemágica Discreta com Python                                                         ???
# lucasicf                         Python ao invés de Shell Script! Como?                                                 ???
# neldevfull                       Porquê Mr. Robot usa Python?                                                           ???
# ocarneiro                         Python para malabaristas - uma introdução ao O...                              Iniciantes
# ssjunior                          Escalabilidade de aplicativos utilizando Celer...                                     Web
#                                   Real Time Django usando Redis e Websockets                                            Web
# Álvaro Justen                    Dados Tabulares: A Maneira Pythônica                                                   ???
#
# [95 rows x 1 columns]

# %%
df.groupby('categoria').count()
# Out:
#                    autor  titulo
# categoria
# ???                   72      72
# Carreira               2       2
# Comunidade             2       2
# Desktop                1       1
# DevOps                 2       2
# Escalabilidade         1       1
# Iniciantes             4       4
# Machine Learning       1       1
# Mobile                 1       1
# Performance            1       1
# Python Científico      4       4
# REST                   1       1
# Teste                  1       1
# WEB                    3       3
# Web                    5       5
# intermediário          1       1
